# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# Agregar el directorio padre
# Método 1: Ruta relativa
# sys.path.append('../AppOO')
# ruta_appoo = r'C:\Users\InversionesWildaga\Documents\MyPython\AppOO'
# sys.path.append(ruta_appoo)

print(sys.path)

print("hola")

engine = create_engine(
    "mysql+pymysql://root:Daga2004@localhost/bdinv"
)
# Out:
# ['C:\\Users\\InversionesWildaga\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\InversionesWildaga\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\InversionesWildaga\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\InversionesWildaga\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\InversionesWildaga\\Documents\\MyPython\\.venv', '', 'c:\\Users\\InversionesWildaga\\Documents\\MyPython\\.venv\\Lib\\site-packages', 'c:\\Users\\InversionesWildaga\\Documents\\MyPython\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\InversionesWildaga\\Documents\\MyPython\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\InversionesWildaga\\Documents\\MyPython\\.venv\\Lib\\site-packages\\Pythonwin', '../AppOO', 'C:\\Users\\InversionesWildaga\\Documents\\MyPython\\AppOO']
# hola

# %%
query = """ SELECT * FROM bdinv.diaria_cnv
order by fecha DESC
"""
df = pd.read_sql(query, engine)
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3186 non-null   int64
#  1   fecha                3186 non-null   object
#  2   codCAFCI             3186 non-null   int64
#  3   fondo                3186 non-null   object
#  4   moneda               3186 non-null   object
#  5   region               3186 non-null   object
#  6   horizonte            3186 non-null   object
#  7   valorActual          3186 non-null   float64
#  8   valorAnterior        3186 non-null   float64
#  9   variacion            3186 non-null   float64
#  10  valorPesos           3186 non-null   float64
#  11  variacion30dias      3186 non-null   float64
#  12  variacion60dias      3186 non-null   float64
#  13  variacion90dias      3186 non-null   float64
#  14  patrimonioActual     3186 non-null   float64
# ...
